# %%
# pearson, spearman, t-test, chisquare, regression

import numpy as np
from scipy.stats import pearsonr, spearmanr, chisquare, ttest_ind

from sklearn.linear_model import LinearRegression

import pandas as pd
from IPython.display import Markdown, display

import plotly.offline as py
import plotly.graph_objs as go
py.init_notebook_mode(connected=True)

import warnings
warnings.filterwarnings('ignore')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
ALPHA = 0.05
DEFAULT_COLOR = 'lightseagreen'

# %%
def table(data, cols):
    
    def bounded_join(inp, sep):
        return sep + sep.join(inp) + sep
    
    vsep, hsep = "|", "-"
    
    head = "{}\n{}".format(bounded_join(cols, vsep),
                           bounded_join([hsep] * len(cols), vsep))
    markdown = head
    
    for row in data:
        srow = list(map(str, row))
        markdown += "\n" + bounded_join(srow, vsep)
    
    display(Markdown(markdown))

# %%
df = pd.read_csv("day.csv")
df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# ### Correlations

# %%
def corr_table(pairs):
    table = []
    for p in pairs:
        col_one, col_two = df[p[0]], df[p[1]]
        pearson = pearsonr(col_one, col_two)[0]
        spearman = spearmanr(col_one, col_two).correlation
        table.append(["{} / {}".format(p[0], p[1]), 
                  "{:.3f}".format(pearson), 
                  "{:.3f}".format(spearman)])
    return table

# %%
cols = ["variables", "pearson", "spearman"]

pairs = [["temp", "cnt"], ["windspeed", "cnt"], ["hum", "cnt"]]

table(corr_table(pairs), cols)
# Out:
# |variables|pearson|spearman|
# |-|-|-|
# |temp / cnt|0.627|0.622|
# |windspeed / cnt|-0.235|-0.217|
# |hum / cnt|-0.101|-0.098|

# %%
cols = ["variables", "pearson", "spearman"]

pairs = [["temp", "casual"], ["windspeed", "casual"], ["hum", "casual"]]

table(corr_table(pairs), cols)
# Out:
# |variables|pearson|spearman|
# |-|-|-|
# |temp / casual|0.543|0.667|
# |windspeed / casual|-0.168|-0.180|
# |hum / casual|-0.077|-0.071|

# %%
# correlation between binary and continuos variables

cols = ["variables", "pearson", "spearman"]

pairs = [["holiday", "cnt"], ["weathersit", "cnt"], ["yr", "cnt"]]

table(corr_table(pairs), cols)
# Out:
# |variables|pearson|spearman|
# |-|-|-|
# |holiday / cnt|-0.068|-0.064|
# |weathersit / cnt|-0.297|-0.272|
# |yr / cnt|0.567|0.572|

# %% [markdown]
# ### T-test

# %%
def plotly_boxplot(input_data):
    visual_data = []
    for y in input_data:
        visual_data.append(go.Box(y=input_data[y], name=y, 
                                  marker=dict(color=DEFAULT_COLOR)))
    
    MARGIN = dict(l=50, r=30, b=20, t=30)
    PLOT_HEIGHT = 250
    PLOT_WIDTH = 300
    layout = go.Layout(height=PLOT_HEIGHT, width=PLOT_WIDTH, margin=MARGIN, 
                       showlegend=False)

    fig = go.Figure(data=visual_data, layout=layout)
    py.iplot(fig, show_link=False)

# %%
workday_cnt = df[df['workingday'] == 1]['cnt']
weekend_cnt = df[df['workingday'] == 0]['cnt']

first_year_cnt = df[df['yr'] == 0]['cnt']
second_year_cnt = df[df['yr'] == 1]['cnt']

# %%
plotly_boxplot({"workday" : workday_cnt, "weekend" : weekend_cnt})
# Out:
# <div id="41b96e8a-be15-4bc5-b787-f4367f7cf867" style="height: 250px; width: 300px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             
"linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('ae21eae0-fda8-4a8b-874c-fd095f98a96d',{});}).then(function(){Plotly.animate('ae21eae0-fda8-4a8b-874c-fd095f98a96d');})
#         });</script>

# %%
# H0: samples have equal means

# %%
# just example
# for t-test data must have normal distribution
# else non-parametric Mann-Whitney rank test recommended

t_weekdays = ttest_ind(workday_cnt, weekend_cnt)

t_years = ttest_ind(first_year_cnt, second_year_cnt)

cols = ["variables", "p-value", "H0 accepted"]

t_table = [["workday / weekend", "{:.2e}".format(t_weekdays.pvalue), 
            t_weekdays.pvalue > ALPHA], 
           ["1st year / 2nd year", "{:.2e}".format(t_years.pvalue), 
            t_years.pvalue > ALPHA]]

table(t_table, cols)
# Out:
# |variables|p-value|H0 accepted|
# |-|-|-|
# |workday / weekend|9.85e-02|True|
# |1st year / 2nd year|2.48e-63|False|

# %% [markdown]
# ### Linear Regression

# %%
def scatter(x, y, color, mode): 
    return go.Scatter(x=x, y=y,
                      mode=mode,
                      marker=dict(opacity=0.5, color=color))

# %%
x = np.array(df['temp']).reshape(-1, 1)
y = np.array(df['cnt']).reshape(-1, 1)
lr = LinearRegression().fit(x, y);

# %%
n = len(y)
lr_values = lr.predict(x).reshape(-1)
exp_values = np.array(y).reshape(-1)

# %%
print("a = {:.2f}".format(lr.coef_[0][0]))
print("b = {:.2f}".format(lr.intercept_ [0]))
print("r^2 = {:.2f}".format(np.sqrt(sum((lr_values-exp_values)**2)/(n))))
# Out:
# a = 6640.71
# b = 1214.64
# r^2 = 1507.32

# %%
x1, y1 = df['temp'], df['cnt']
x2, y2  = x.reshape(-1), lr.predict(x).reshape(1,-1)[0].reshape(-1)

# %%
points = scatter(x1, y1, DEFAULT_COLOR, 'markers')
line = scatter(x2, y2, 'black', 'lines')

MARGIN = dict(l=70, r=30, b=40, t=30)
PLOT_HEIGHT = 350
PLOT_WIDTH = 500

layout = go.Layout(height=PLOT_HEIGHT, width=PLOT_WIDTH, margin=MARGIN,
                   hovermode='closest', showlegend=False,
                  xaxis=dict(title='temp', titlefont=dict(size=15)), 
                   yaxis=dict(title='cnt', titlefont=dict(size=15)))

fig = go.Figure(data=[points, line], layout=layout)
py.iplot(fig, show_link=False)
# Out:
# <div id="c7086677-b8fd-47fe-a898-91e6544a61d3" style="height: 350px; width: 500px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'c7086677-b8fd-47fe-a898-91e6544a61d3',
#             [{"marker": {"color": "lightseagreen", "opacity": 0.5}, "mode": "markers", "x": [0.344167, 0.363478, 0.196364, 0.2, 0.22695700000000002, 0.204348, 0.196522, 0.165, 0.13833299999999998, 0.150833, 0.16909100000000002, 0.172727, 0.165, 0.16087, 0.23333299999999998, 0.231667, 0.175833, 0.216667, 0.292174, 0.261667, 0.1775, 0.0591304, 0.0965217, 0.0973913, 0.223478, 0.2175, 0.195, 0.203478, 0.196522, 0.216522, 0.180833, 0.192174, 0.26, 0.18695699999999998, 0.211304, 0.23333299999999998, 0.285833, 0.271667, 0.220833, 0.134783, 0.144348, 0.189091, 0.2225, 0.31652199999999997, 0.415, 0.26608699999999996, 0.318261, 0.43583299999999997, 0.521667, 0.399167, 0.285217, 0.303333, 0.182222, 0.221739, 0.295652, 0.364348, 0.2825, 0.343478, 0.407273, 0.266667, 0.335
.53, 0.456667, 0.341667, 0.274167, 0.329167, 0.463333, 0.4475, 0.416667, 0.440833, 0.37333299999999997, 0.375, 0.375833, 0.459167, 0.503478, 0.458333, 0.325, 0.3125, 0.31416700000000003, 0.299167, 0.330833, 0.385833, 0.4625, 0.41, 0.265833, 0.290833, 0.275, 0.220833, 0.238333, 0.2825, 0.3175, 0.4225, 0.375, 0.258333, 0.238333, 0.276667, 0.385833, 0.428333, 0.423333, 0.37333299999999997, 0.3025, 0.274783, 0.321739, 0.325, 0.29913, 0.248333, 0.311667, 0.41, 0.37, 0.273043, 0.15, 0.1075, 0.265833, 0.334167, 0.393333, 0.3375, 0.224167, 0.308696, 0.274167, 0.3825, 0.274167, 0.18, 0.166667, 0.19, 0.37304299999999996, 0.303333, 0.19, 0.2175, 0.173333, 0.1625, 0.218333, 0.3425, 0.294167, 0.341667, 0.425, 0.315833, 0.282 ...

# %%
def plotly_barchart(x, y):
    visual_data = [go.Bar(x=x, y=y, marker=dict(color=DEFAULT_COLOR))]

    margin = dict(l=40, r=30, b=30, t=30)
    layout = go.Layout(height=250, width=400, margin=margin)

    fig = go.Figure(data=visual_data, layout=layout)
    py.iplot(fig, show_link=False)

# %% [markdown]
# ### Chi-square

# %%
def bar(x, y, color, name=None):
    return go.Bar(x=x, y=y, marker=dict(opacity=0.8, color=color), name=name)


def scatter(x, y, color, mode, symbol=None, marker_size=None, name=None): 
    return go.Scatter(x=x, y=y,
                      mode=mode, name=name,
                      line=dict(dash='dot'),
                      marker=dict(color=color, symbol=symbol, 
                                  size=marker_size))

# %%
def histogram(s, bins):
    hist, edges = np.histogram(s, bins=bins)
    centers = (edges[1:] + edges[:-1]) / 2
    return hist, centers


def normalize(s):
    return (s - np.mean(s)) / np.std(s)


def norm_distr(x):
    return np.exp((-x ** 2) / 2) / np.sqrt(2 * np.pi)

# %%
hum = df['hum']
hist, centers = histogram(normalize(hum), bins=np.linspace(-2, 2, 5))
x_interp = np.linspace(-2, 2)

# %%
hist_sum = sum(hist)
theory_hist =  hist_sum * norm_distr(centers)
theory_distr = hist_sum * norm_distr(-x_interp)

# %%
data = [bar(centers, hist, DEFAULT_COLOR, name="hist"),
    
        scatter(centers, theory_hist, 
                color='black', mode='markers', 
                symbol="x", marker_size=10, name="theory hist"),
    
        scatter(x_interp, theory_distr, 
                color='black', mode='lines', name="theory")]

MARGIN = dict(l=40, r=30, b=30, t=30)
PLOT_HEIGHT = 250
PLOT_WIDTH = 400

layout = go.Layout(height=PLOT_HEIGHT, width=PLOT_WIDTH, margin=MARGIN)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, show_link=False)
# Out:
# <div id="221ef341-e298-4ec3-9138-7fed41fba445" style="height: 250px; width: 400px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '221ef341-e298-4ec3-9138-7fed41fba445',
#             [{"marker": {"color": "lightseagreen", "opacity": 0.8}, "name": "hist", "x": [-1.5, -0.5, 0.5, 1.5], "y": [103.0, 251.0, 247.0, 105.0], "type": "bar", "uid": "ec01a3c6-1973-11e9-a827-3c15c2cf2370"}, {"line": {"dash": "dot"}, "marker": {"color": "black", "size": 10, "symbol": "x"}, "mode": "markers", "name": "theory hist", "x": [-1.5, -0.5, 0.5, 1.5], "y": [91.43942254011957, 248.55812069559548, 248.55812069559548, 91.43942254011957], "type": "scatter", "uid": "ec01a6a8-1973-11e9-bf6e-3c15c2cf2370"}, {"line": {"dash": "dot"}, "marker": {"color": "black"}, "mode": "lines", "name": "theory", "x": [-2.0, -1.9183673469387754, -1.836734693877551, -1.7551020408163265, -1.6734693877551021, -1.5918367346938775, -1.510204081632653, -1.4285714285714286, -1.3469387755102042, -1.2653061224489797, -1.183673469387755, -1.1020408163265307, -1.0204081632653061, -0.9387755102040818, -0.8571428571428572, -0.7755102040816328, -0.6938775510204083, -0.6122448979591837, -0.5306122448979593, -0.44897959183673475, -0.3673469387755104, -0.2857142857142858, -0.20408163265306145, -0.12244897959183687, -0.04081632653061229, 0.04081632653061229, 0.12244897959183643, 0.204081632653061, 0.2857142857142856, 0.36734693877551017, 0.4489795918367343, 0.5306122448979589, 0.6122448979591835, 0.693877551020408, 0.7755102040816326, 0.8571428571428568, 0.9387755102040813, 1.020408163265306, 1.1020408163265305, 1.1836734693877546, 1.2653061224489792, 1.3469387755102038, 1.4285714285714284, 1.510204081632653, 1.591836734693877, 1.6734693877551017, 1.7551020408163263, 1.8367346938775508, 1.9183673469387754, 2.0], "y": [38.117622358310776, 44.72846345889808, 52.137243323484455, 60.36956682515648, 69.43748201652325, 79.33700054785514, 90.04580814189585, 101.52129110070098, 113.69900752221807, 126.49172772298448, 139.78915661303233, 153.45843120396813, 167.3454593209159, 181.27713176147788, 195.06440098735752, 208.5061768481873, 221.39394614529945, 233.51698065360097, 244.66796025317427, 254.64880671671952, 263.27650180598243, 270.38865252061385, 275.8485678393322, 279.54962554704406, 281.4187343650065, 281.4187343650065, 279.54962554704406, 275.84856783933225, 270.38865252061385, 263.27650180598243, 254.64880671671958, 244.6679602531743, 233.516980653601, 221.39394614529948, 208.50617684818732, 195.0644009873576, 181.2771317614779, 167.34545932091592, 153.45843120396816, 139.7891566130324, 126.49172772298456, 113.69900752221812, 101.52129110070102, 90.04580814189585, 79.33700054785518, 69.4374820165233, 60.3695668251565, 52.13724332348448, 44.72846345889808, 38.117622358310776], "type": "scatter", "uid": "ec01a838-1973-11e9-ad53-3c15c2cf2370"}],
#             {"height": 250, "margin": {"b": 30, "l": 40, "r": 30, "t": 30}, "width": 400},
#             {"showLink": false, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('221ef341-e298-4ec3-9138-7fed41fba445',{});}).then(function(){Plotly.animate('221ef341-e298-4ec3-9138-7fed41fba445');})
#         });</script>

# %%
chi_data = []

for j in [4, 5, 6, 7]:
    hist, centers = histogram(normalize(hum), bins=np.linspace(-2, 2, j))

    pvalue = chisquare(hist, sum(hist) * norm_distr(centers)).pvalue
    
    chi_data.append([j, pvalue])

# %%
# H0: samples have equal distributions

# %%
chi_print = [[row[0], "{:.2e}".format(row[1]), row[1] > ALPHA] for row in chi_data]

table(chi_print, ["n bins","p-value", "H0 accepted"])
# Out:
# |n bins|p-value|H0 accepted|
# |-|-|-|
# |4|8.38e-21|False|
# |5|3.20e-01|True|
# |6|1.40e-06|False|
# |7|5.04e-20|False|
