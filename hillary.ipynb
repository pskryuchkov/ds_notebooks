# %%
import re
import operator
from pprint import pprint
from random import sample
from collections import Counter, Iterable

import numpy as np
import matplotlib.pyplot as plt

from sklearn.manifold import TSNE
from sklearn.cluster import KMeans, MiniBatchKMeans
from sklearn.feature_extraction.text import TfidfVectorizer

import pandas as pd

from gensim.models import Phrases

import plotly.offline as py
import plotly.graph_objs as go
py.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
aliases = pd.read_csv("Aliases.csv")
receivers = pd.read_csv("EmailReceivers.csv")
emails = pd.read_csv("Emails.csv")
persons = pd.read_csv("Persons.csv")

# %%
print(aliases.shape)
print(receivers.shape)
print(emails.shape)
print(persons.shape)
# Out:
# (850, 3)
# (9306, 3)
# (7945, 22)
# (513, 2)

# %%
aliases.head()
# Out:
#    Id                         Alias  PersonId
# 0   1                111th congress         1
# 1   2  agna usemb kabul afghanistan         2
# 2   3                            ap         3
# 3   4                      asuncion         4
# 4   5                          alec         5

# %%
receivers.head()
# Out:
#    Id  EmailId  PersonId
# 0   1        1        80
# 1   2        2        80
# 2   3        3       228
# 3   4        3        80
# 4   5        4        80

# %%
emails.head()
# Out:
#    Id  DocNumber                                    MetadataSubject  \
# 0   1  C05739545                                                WOW
# 1   2  C05739546  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
# 2   3  C05739547                                      CHRIS STEVENS
# 3   4  C05739550                         CAIRO CONDEMNATION - FINAL
# 4   5  C05739554  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
#
#      MetadataTo       MetadataFrom  SenderPersonId           MetadataDateSent  \
# 0             H  Sullivan, Jacob J            87.0  2012-09-12T04:00:00+00:00
# 1             H                NaN             NaN  2011-03-03T05:00:00+00:00
# 2            ;H    Mills, Cheryl D            32.0  2012-09-12T04:00:00+00:00
# 3             H    Mills, Cheryl D            32.0  2012-09-12T04:00:00+00:00
# 4  Abedin, Huma                  H            80.0  2011-03-11T05:00:00+00:00
#
#         MetadataDateReleased  \
# 0  2015-05-22T04:00:00+00:00
# 1  2015-05-22T04:00:00+00:00
# 2  2015-05-22T04:00:00+00:00
# 3  2015-05-22T04:00:00+00:00
# 4  2015-05-22T04:00:00+00:00
#
#                                      MetadataPdfLink MetadataCaseNumber  \
# 0  DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739545...       F-2015-04841
# 1  DOCUMENTS/HRC_Email_1_296/HRCH1/DOC_0C05739546...       F-2015-04841
# 2  DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739547...       F-2015-04841
# 3  DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739550...       F-2015-04841
# 4  DOCUMENTS/HRC_Email_1_296/HRCH1/DOC_0C05739554...       F-2015-04841
#
#                          ...                         ExtractedTo  \
# 0                        ...                                 NaN
# 1                        ...                                 NaN
# 2                        ...                                  B6
# 3                        ...                                 NaN
# 4                        ...                                 NaN
#
#                               ExtractedFrom         ExtractedCc  \
# 0  Sullivan, Jacob J <Sullivan11@state.gov>                 NaN
# 1                                       NaN                 NaN
# 2       Mills, Cheryl D <MillsCD@state.gov>        Abedin, Huma
# 3       Mills, Cheryl D <MillsCD@state.gov>  Mitchell, Andrew B
# 4                                       NaN                 NaN
#
#                         ExtractedDateSent ExtractedCaseNumber  \
# 0  Wednesday, September 12, 2012 10:16 AM        F-2015-04841
# 1                                     NaN        F-2015-04841
# 2  Wednesday, September 12, 2012 11:52 AM        F-2015-04841
# 3   Wednesday, September 12,2012 12:44 PM        F-2015-04841
# 4                                     NaN        F-2015-04841
#
#   ExtractedDocNumber ExtractedDateReleased ExtractedReleaseInPartOrFull  \
# 0          C05739545            05/13/2015              RELEASE IN FULL
# 1          C05739546            05/13/2015              RELEASE IN PART
# 2          C05739547            05/14/2015              RELEASE IN PART
# 3          C05739550            05/13/2015              RELEASE IN PART
# 4          C05739554            05/13/2015              RELEASE IN PART
#
#                                    ExtractedBodyText  \
# 0                                                NaN
# 1  B6\nThursday, March 3, 2011 9:45 PM\nH: Latest...
# 2                                                Thx
# 3                                                NaN
# 4  H <hrod17@clintonemail.com>\nFriday, March 11,...
#
#                                              RawText
# 0  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 1  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 2  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 3  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 4  B6\nUNCLASSIFIED\nU.S. Department of State\nCa...
#
# [5 rows x 22 columns]

# %%
persons.head()
# Out:
#    Id                          Name
# 0   1                111th Congress
# 1   2  AGNA USEMB Kabul Afghanistan
# 2   3                            AP
# 3   4                      ASUNCION
# 4   5                          Alec

# %%
def sort_dict(d):
    return sorted(d.items(), key=operator.itemgetter(1), reverse=True)

# %%
sort_dict(Counter((" ".join(emails['ExtractedBodyText'].astype(str).tolist())).split(" ")))[:10]
# Out:
# [('the', 25616),
#  ('to', 15707),
#  ('of', 12753),
#  ('and', 12449),
#  ('a', 9781),
#  ('in', 8903),
#  ('that', 5542),
#  ('is', 5403),
#  ('for', 5278),
#  ('on', 4598)]

# %%
body_text = emails[~emails['ExtractedBodyText'].isnull()]['ExtractedBodyText'].astype(str).tolist()

# %% [markdown]
# ### Visualizaton

# %%
def plotly_scatter(x, y, labels):
    trace = go.Scatter(
        x=x, y=y,
        mode='markers',
        text=labels,
        hoverinfo='text',
        marker=dict(opacity=0.5, symbol='cross-dot', color='lightseagreen')
    )
    MARGIN = dict(l=0, r=30, b=0, t=30)
    layout = go.Layout(height=350, width=500, hovermode='closest', margin=MARGIN)
    data = [trace]
    fig = go.Figure(data=data, layout=layout)
    py.iplot(fig, show_link=False)

# %% [markdown]
# ### Text preparation

# %%
stop_words = list(map(lambda x: x.strip(), 
                 open("stopwords.txt", "r").readlines()))

message_base = [x.lower() for x in body_text]

# %%
def tokenize(input_docs):
    tokenized_docs = []
    for j, mail in enumerate(input_docs):
        tokenized_sentences = []

        for sentence in mail.split("\n"):
            processed_str = sentence.split()
            tokenized_sentences.append(processed_str)
        tokenized_docs.append(tokenized_sentences)

    return tokenized_docs

tokenized_messages = tokenize(message_base)

# %%
re_alpha = re.compile(r'[^a-zA-Z]')


def remove_non_alpha(raw_texts):
    filtered_texts = []
    for raw_text in raw_texts:
        text = []
        for tokenized_sentence in raw_text:
            sentence = " ".join(tokenized_sentence)
            sentence = re_alpha.sub(' ', sentence).strip()
            text.append(sentence.split())

        filtered_texts.append(text)
    return filtered_texts


def remove_short_sentences(raw_texts):
    filtered_texts = []
    for raw_text in raw_texts:
        text = []
        for tokenized_sentence in raw_text:
            if len(tokenized_sentence) > 1:
                text.append(tokenized_sentence)
        if text:
            filtered_texts.append(text)
    return filtered_texts


def remove_dates(raw_texts):
    week_days = ['monday', 'tuesday', 'wednesday', 
                 'thursday', 'friday', 'saturday', 'sunday']
    filtered_texts = []
    for raw_text in raw_texts:
        text = []
        for tokenized_sentence in raw_text:
            if tokenized_sentence:
                first_word = re_alpha.sub(' ', tokenized_sentence[0]).strip()
                if not first_word in week_days:
                    text.append(tokenized_sentence)
        filtered_texts.append(text)
    return filtered_texts


def filter_tokens_by_condition(tokenized_texts, condition, debug=False):
    filtered_texts = []
    for raw_text in tokenized_texts:
        text = []
        for raw_sentence in raw_text:
            sentence = []
            for token in raw_sentence:
                if condition(token):
                    sentence.append(token)
                elif debug:
                    print(token)
            text.append(sentence)
        filtered_texts.append(text)
    return filtered_texts
    

def remove_stopwords(tokenized_texts):
    condition = lambda token: not (token in stop_words)
    return filter_tokens_by_condition(tokenized_texts, condition)


def remove_links(tokenized_texts):
    condition = lambda token: not ("http" in token or "www." in token)
    return filter_tokens_by_condition(tokenized_texts, condition)


def remove_emails(tokenized_texts):
    condition = lambda token: not ("@" in token)
    return filter_tokens_by_condition(tokenized_texts, condition)


def remove_shorts(tokenized_texts):
    condition = lambda token: len(token) > 1
    return filter_tokens_by_condition(tokenized_texts, condition)

# %%
filter_pipeline = [remove_emails, 
                    remove_dates,
                    remove_links,
                    remove_non_alpha,
                    remove_stopwords,
                    remove_short_sentences]

filtered_messages = tokenized_messages
for func in filter_pipeline:
    filtered_messages = func(filtered_messages)
    
len(filtered_messages)
# Out:
# 5541

# %%
def flatten(l):
    for el in l:
        if isinstance(el, collections.Iterable) and not isinstance(el, (str, bytes)):
            yield from flatten(el)
        else:
            yield el
       
tokens_counter = Counter(list(flatten(filtered_messages)))
sorted(tokens_counter.items(), key=operator.itemgetter(1), reverse=True)[:10]
# Out:
# [('state', 1927),
#  ('pm', 1847),
#  ('would', 1533),
#  ('secretary', 1349),
#  ('u', 1255),
#  ('obama', 1238),
#  ('said', 1234),
#  ('one', 1178),
#  ('president', 1126),
#  ('office', 1113)]

# %% [markdown]
# ### TF Vectorizer

# %%
tf_data = []

for j, mail in enumerate(filtered_messages):
    sentences = []
    for tokenized_sentence in mail:
        sentences.append(" ".join(tokenized_sentence))
    tf_data.append(". ".join(sentences))

# %%
vectorizer = TfidfVectorizer(max_features=3000, min_df=3)
X = vectorizer.fit_transform(tf_data)

X.shape
# Out:
# (5541, 3000)

# %%
def shrink_string(s, max_len=50):
    if len(s) > max_len:
        return s[:max_len] + "..."
    else:
        return s

# %%
samples = sample(list(zip(X.toarray(), tf_data)), 1000)

sample_points = [x[0] for x in samples]
sample_labels = [shrink_string(x[1]) for x in samples]

# %%
X_embedded = TSNE(n_components=2).fit_transform(sample_points)

# %%
plotly_scatter([x[0] for x in X_embedded], 
         [x[1] for x in X_embedded], sample_labels);
# Out:
# <div id="426c3cfa-a6b9-4600-b9f3-134ad1869b0d" style="height: 350px; width: 500px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '426c3cfa-a6b9-4600-b9f3-134ad1869b0d',
#             [{"hoverinfo": "text", "marker": {"color": "lightseagreen", "opacity": 0.5, "symbol": "cross-dot"}, "mode": "markers", "text": ["gw dodging ask letter drafted could send asap maki...", "back two columns", "question congressional elections definitely vote p...", "sorry first ve heard philippe sitting shuttle take...", "doc strategic dialogue press clips march doc strat...", "jiloty lauren c. abedin huma. mini schedule wednes...", "also pls get copy president nobel speech", "sure video conf w chris hill next weeks", "jill dougherty report much better lead maybe chanc...", "derek comments redline text oscar print see", "saw wapo article w photo wondered whether list", "enjoy see message pfs", "melanne sent emails burns forwarding kay warren ly...", "calling pm fm yang. australian fm smith asking tal...", "huma reminded wanted get structured agenda weeklie...", "release part. drove roads live lots packed hard sn...", "thanks back got waylaid long detour around iceland...", "wow fast great. worry reporter reading quotes back...", "fax dc house", "revised draft prayer breakfast remarks coming min ...", "per earlier email", "interesting reports pal side moment talk secure", "written family condolence letter", "try find maybe want associated w big cities lot su...", "esther keep sending updates", "h case haven seen fully articulated view netanyahu...", "effort liberal balance g o p groups. michael luo. ...", "tom expressed different view hof trip perspective ...", "let tomorrow mtp ok", "re email went", "also meeting w potus wh dinner need work w jake ye...", "rooms set ups. one conference table one sofas chai...", "pis print", "recall hearing particular project quick analysis f...", "h fyi iran document gary sick sent sid. gary sick....", "re stone harbour llc. marty m copying kris asking ...", "yang travel. free tonite. may work tomorrow", "zelaya tentatively understand might fall thru curr...", "think b", "course book today. lona valmoro. special assistant...", "update tom", "u r still wjc landed brazil refuel ground hour cal...", "doctrine surprises become personal mantra glad lik...", "pis add henry kissinger", "image jpg image jpg image jpg image jpg image jpg ...", "m back ground way house", "madam secretary really terrific work morning great...", "importance high", "trying bit mad two proper grounds make donors less...", "able correct record travel", "gail collins. m working addresses call grid ll sen...", "hfac remarks courier. mitchell report courier. ver...", "good morning. cheryl trying reach follow weekend c...", "yes call later tonite. b fast vi marty. call re", "sent via blackberry", "yes went. nephews till halftime. dougs party secon...", "wpost editorial. thought argument made yesterday h...", "good paul look forward reading", "trying figure actually happening", "call participants. counselor cheryl mills. senator...", "trying reach yellow phone. sun oct pm h wrote", "fyi traffic. mills cheryl d. fw sanctions. millscd...", "ok thx", "see nelson support ask tell measure spoke byrd peo...", "also print", "let discuss asap m free", "ll meet arizona sounds like ok", "k give directly", "like man doug justin met w last night coming today", "thank message office today intermittent access ema...", "currently office official travel checking e mail p...", "long time politico close rajiv ghandi iii send bio...", "info eric john u asked. ops contact eric passed me...", "madam secretary. m writing remarks town hall saraj...", "fyi note sent denis", "called home", "re continuing make small tweaks cfr speech wanted ...", "ve printed give copy secretary also huma", "h distant early warning sid. hrc memo dew docx", "get lisa lunch rescheduled d letter dave service. ...", "part b b", "jack trying get calendar thurs", "ever ask else take call directly b", "actually called back took earlier time strobe lobo...", "pls pu n call list letter wishing well etc b", "sorry confirm", "dear cherie. could make time meet dc weeks june th ...

# %% [markdown]
# ### Doc2Vec

# %%
from collections import namedtuple
import re

TaggedSentence = namedtuple('SentimentDocument', 'words tags')

tagged_sentences = []

for j, mail in enumerate(filtered_messages):
    for sentence in mail:
        tagged_sentences.append(TaggedSentence(sentence, 
                                               ["doc_{}".format(j)]))

# %%
from gensim.models import Doc2Vec, Word2Vec

model = Doc2Vec(vector_size=300, min_count=6, window=6, workers=4)
model.build_vocab(tagged_sentences)
n_epochs = 6

len(model.wv.vocab.keys())
# Out:
# 7076

# %%
for epoch in range(n_epochs):
    print("epoch", epoch + 1)
    model.train(tagged_sentences, total_examples=len(tagged_sentences), epochs=n_epochs)
# Out:
# epoch 1
# epoch 2
# epoch 3
# epoch 4
# epoch 5
# epoch 6

# %%
X = []
for k in range(len(model.docvecs)):
    X.append(model.docvecs["doc_{}".format(str(k))])

# %%
samples = sample(list(zip(X, tf_data)), 1000)

sample_points = [x[0] for x in samples]
sample_labels = [shrink_string(x[1]) for x in samples]

# %%
X_embedded = TSNE(n_components=2).fit_transform(sample_points)

# %%
plotly_scatter([x[0] for x in X_embedded], 
         [x[1] for x in X_embedded], sample_labels);
# Out:
# <div id="1e784e01-3f30-4451-8f40-0eb3e4c927bc" style="height: 350px; width: 500px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '1e784e01-3f30-4451-8f40-0eb3e4c927bc',
#             [{"hoverinfo": "text", "marker": {"color": "lightseagreen", "opacity": 0.5, "symbol": "cross-dot"}, "mode": "markers", "text": ["plane til eastern easily reachable thereafter", "re another memo backdrop week sid. thrilled presid...", "pretty good stuff", "wouldn closed govt tomorrow decision made difficul...", "pls pull speeches bill gave health care doctor gro...", "lona valmoro. ecial assistant secretary state. dir...", "actually full cabinet meeting today agencies recei...", "fyi sure timing call. terrible news poland. m grou...", "fyi craig way honduras", "come havent. said save afghanistan women. come hav...", "also fyi sure make kim inquiry", "angolans vote president may extend term sbu consti...", "apparently filled pc time immediately jones lands ...", "pm re still talking british think reasonably posit...", "seen see get", "eap bosworth apparently fine per. likely judgment ...", "lona went talk u. changed obviously", "dan stay monday work. next step would work toi", "hurricane tomas route haiti hit nov right southern...", "miss since return th look forward bill others w th...", "cherie blair. message back friend. thank immediate...", "told andrew would things requested memo talk sched...", "also allawi appears", "still working througn trip planning saudi still ot...", "good answers blackwater allegations exactly said", "good far", "immigrant visa services honduras", "marshall capricia p verveer melanne. release part", "thnx offer help expo send full list tomorrow would...", "fyi lauren meet renwick remarks. per request set h...", "got word potus agreed host nato summit us spring a...", "napolitano memo came thru", "heading home visit bangladesh remembered great aff...", "sullivan jacob j. fw remarks ambassador alejandro ...", "h roubini right mostly right far one without addit...", "yes taking shuttle. going take train usss party we...", "heard radio cabinet mtg go sending", "see traffic bottom", "strange meeting confirmed several days ago fact of...", "internal assessment someone iran watch office kay ...", "let conf call re w jack whomever else decide", "traded calls haven heard back", "oh dear guess d rather leave present problems know", "mills cheryl d. fw durban language d language. foc...", "hope read pages meeting secretary gates pooled fun...", "fyi case anything want address alec meet weekly dr...", "press event know gordon mentioned find shaun still...", "yes known", "meant write solomon tough critic", "starting little come colleagues folks board", "thank team call people tell explain geneva folks h...", "tom started working confirm afternoon ve talked mi...", "depart private residence en route state department...", "inr report released. western europe publics credit...", "ok definitely keeping open mind seeing suggest lit...", "per call last night. let know make call thx", "fw hello fyi invite. hours obama party st make tam...", "ms bob einhorn asking hold yu call deputy fm curre...", "scheduled calls tomorrow. swedish foreign minister...", "release part", "got invite schwarzenegger conf last night calif se...", "check us thx", "pls print", "m dubrovnik aspen conf home sun day pm reached mon...", "jake sullivar. delivered re unscr dprk. details tx...", "reines philippe. sullivan jacob j h mchale judith....", "sullivan jacob j. h mills cheryl d. huma abedin. r...", "text set among things re still working whether men...", "campbell kurt m. re n korea. secretary clinton", "thx mike", "would good idea pass copies nytimes magazine issue...", "sent via blackberry", "abedin huma. fw north korea fires third missile sb...", "jp ist fyi ci ra h fin plifarthtally. flrorn carte...", "getting fax shortly rough draft big speech still m...", "spoke w french fm kouchner", "m going skip yale today. assuming ok", "fyi bill talk senator specter went fine specter gl...", "release part", "re fyi murdoch makes move cameron attack bbc follo...", "took hours got home noon today. talk pm tonight wo...", "mills cheryl d. ...
